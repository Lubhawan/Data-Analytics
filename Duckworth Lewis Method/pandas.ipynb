# %%
import pandas as pd

# %%
# !pip install pandas

# %%
diamonds = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/diamonds.csv')
print(diamonds)
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
diamonds.groupby(['cut','color','clarity']).agg('mean')
# Out:
#                             carat      depth      table        price  \
# cut       color clarity
# Fair      D     I1       1.877500  65.600000  56.750000  7383.000000
#                 IF       0.380000  60.766667  58.000000  1619.666667
#                 SI1      0.913793  64.634483  58.758621  4273.344828
#                 SI2      1.016964  64.703571  58.642857  4355.142857
#                 VS1      0.630000  63.160000  57.800000  2921.200000
# ...                           ...        ...        ...          ...
# Very Good J     SI2      1.360937  61.835938  58.772656  5992.898438
#                 VS1      0.964917  62.024167  58.043333  4339.591667
#                 VS2      1.140543  61.868478  58.302717  5325.548913
#                 VVS1     0.765263  61.684211  58.026316  3175.526316
#                 VVS2     1.102069  62.410345  58.344828  5960.448276
#
#                                 x         y         z
# cut       color clarity
# ...

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds['cut'].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(diamonds['cut'])
# Out:
# (array([21551.,     0., 13791.,     0.,     0.,  4906.,     0., 12082.,
#             0.,  1610.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
diamonds[['carat','depth','cut','price']].groupby('cut').agg('mean')
# Out:
#               carat      depth        price
# cut
# Fair       1.046137  64.041677  4358.757764
# Good       0.849185  62.365879  3928.864452
# Ideal      0.702837  61.709401  3457.541970
# Premium    0.891955  61.264673  4584.257704
# Very Good  0.806381  61.818275  3981.759891

# %%
gby.agg(['mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File d:\anaconda\envs\hia\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File d:\anaconda\envs\hia\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File d:\anaconda\envs\hia\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
diamonds.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
diamonds.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# price        int64
# x          float64
# y          float64
# z          float64
# dtype: object

# %%
diamonds.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
diamonds['cut']
# Out:
# 0            Ideal
# 1          Premium
# 2             Good
# 3          Premium
# 4             Good
#            ...
# 53935        Ideal
# 53936         Good
# 53937    Very Good
# 53938      Premium
# 53939        Ideal
# Name: cut, Length: 53940, dtype: object

# %%
diamonds.iloc[5:10]
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %%
diamonds[(diamonds['depth']> 60) | (diamonds['table']<50)].shape[0]
# Out:
# 48315

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
diamonds.in
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
cut_counts = diamonds['cut'].value_counts()
cut_counts = cut_counts[cut_counts > 5000].index.tolist()

# %%
cut_counts
# Out:
# ['Ideal', 'Premium', 'Very Good']

# %%
diamonds[diamonds['cut'].isin(cut_counts)].groupby('cut')['price'].mean().round(2)
# Out:
# cut
# Ideal        3457.54
# Premium      4584.26
# Very Good    3981.76
# Name: price, dtype: float64

# %%
category_avg_prices = diamonds.groupby("cut")['price'].transform('mean').round(2)

# %%
diamonds['category_wise_price_dev'] = diamonds['price'] - category_avg_prices

# %%
diamonds[diamonds['category_wise_price_dev']>0]
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 3769    1.02      Ideal     G      I1   61.2   56.0   3459  6.47  6.50  3.97
# 3771    0.73      Ideal     G     VS1   60.9   59.0   3459  5.79  5.83  3.54
# 3775    1.03      Ideal     F     SI2   62.6   57.0   3461  6.44  6.40  4.02
# 3779    1.06      Ideal     F     SI2   62.7   56.0   3461  6.52  6.47  4.07
# 3783    0.96      Ideal     I     VS2   59.8   57.0   3462  6.42  6.39  3.83
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 27745   2.00  Very Good     H     SI1   62.8   57.0  18803  7.95  8.00  5.01
# 27746   2.07      Ideal     G     SI2   62.5   55.0  18804  8.20  8.13  5.11
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
#
#        category_wise_price_dev
# ...

# %%
new_diamonds = diamonds

# %%
new_diamonds.sort_values(by='price', ascending=False, inplace=True)

# %%
new_diamonds.drop_duplicates(subset=['cut'])
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 27749   2.29    Premium     I     VS2   60.8   60.0  18823  8.50  8.47  5.16
# 27748   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90  7.97  5.04
# 27747   1.51      Ideal     G      IF   61.7   55.0  18806  7.37  7.41  4.56
# 27739   2.80       Good     G     SI2   63.8   58.0  18788  8.90  8.85  0.00
# 27646   2.01       Fair     G     SI1   70.6   64.0  18574  7.43  6.64  4.69
#
#        category_wise_price_dev
# 27749                 14238.74
# 27748                 14836.24
# 27747                 15348.46
# 27739                 14859.14
# 27646                 14215.24

# %%
diamonds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53940 entries, 27749 to 0
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   carat                    53940 non-null  float64
#  1   cut                      53940 non-null  object
#  2   color                    53940 non-null  object
#  3   clarity                  53940 non-null  object
#  4   depth                    53940 non-null  float64
#  5   table                    53940 non-null  float64
#  6   price                    53940 non-null  int64
#  7   x                        53940 non-null  float64
#  8   y                        53940 non-null  float64
#  9   z                        53940 non-null  float64
#  10  category_wise_price_dev  53940 non-null  float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 4.9+ MB

# %%
diamonds.groupby('clarity').agg({'clarity':'count', 'price':['mean','max','min']})
# Out:
#         clarity        price
#           count         mean    max  min
# clarity
# I1          741  3924.168691  18531  345
# IF         1790  2864.839106  18806  369
# SI1       13065  3996.001148  18818  326
# SI2        9194  5063.028606  18804  326
# VS1        8171  3839.455391  18795  327
# VS2       12258  3924.989395  18823  334
# VVS1       3655  2523.114637  18777  336
# VVS2       5066  3283.737071  18768  336

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  category_wise_price_dev
# count  53940.000000  53940.000000             53940.000000
# mean       5.734526      3.538734                 0.000514
# std        1.142135      0.705699              3963.700470
# ...

# %%
import pandas as pd

# %%
dates = pd.date_range(start='21-07-2023', end='21-08-2025', freq='D')

# %%
import numpy as np

# %%
daily_sales = []
for date in dates:
    if date.dayofweek>5:
        sales = np.random.randint(1000, 5000)
    else:
        sales = np.random.randint(100, 1000)
    
    daily_sales.append(
    {'date':date,
     'sales':sales}
     )

# %%
df = pd.DataFrame(daily_sales)

# %%
df
# Out:
#           date  sales
# 0   2023-07-21    334
# 1   2023-07-22    959
# 2   2023-07-23   3368
# 3   2023-07-24    213
# 4   2023-07-25    392
# ..         ...    ...
# 758 2025-08-17   2549
# 759 2025-08-18    495
# 760 2025-08-19    815
# 761 2025-08-20    561
# 762 2025-08-21    632
#
# [763 rows x 2 columns]

# %%
df['day_of_week'] = df['date'].dt.day_name()

# %%
df
# Out:
#           date  sales day_of_week
# 0   2023-07-21    334      Friday
# 1   2023-07-22    959    Saturday
# 2   2023-07-23   3368      Sunday
# 3   2023-07-24    213      Monday
# 4   2023-07-25    392     Tuesday
# ..         ...    ...         ...
# 758 2025-08-17   2549      Sunday
# 759 2025-08-18    495      Monday
# 760 2025-08-19    815     Tuesday
# 761 2025-08-20    561   Wednesday
# 762 2025-08-21    632    Thursday
#
# [763 rows x 3 columns]

# %%
avg_sales = df.groupby('day_of_week').agg('mean')

# %%
avg_sales['sales'].idxmax()
# Out:
# 'Sunday'

# %%
data = {
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah'],
    'Department': ['HR', 'IT', 'IT', 'HR', 'Finance', 'IT', 'Finance', 'HR'],
    'Salary': [60000, 85000, 72000, 58000, 90000, 75000, 82000, 62000]
}

# %%
df = pd.DataFrame(data)

# %%
df_sorted = df.sort_values(by='Salary',ascending=False)

# %%
df_sorted['rank'] = df_sorted.groupby('Department').agg('Salary').rank(method='first', ascending=False)

# %%
df_sorted
# Out:
#   Employee Department  Salary  rank
# 4      Eve    Finance   90000   1.0
# 1      Bob         IT   85000   1.0
# 6    Grace    Finance   82000   2.0
# 5    Frank         IT   75000   2.0
# 2  Charlie         IT   72000   3.0
# 7   Hannah         HR   62000   1.0
# 0    Alice         HR   60000   2.0
# 3    David         HR   58000   3.0

# %%
df_salary = df.groupby('Department').agg({'Salary':'mean'})

# %%
d_list = df_salary[df_salary['Salary']>70000].index.to_list()

# %%
df_sorted[df_sorted['Department'].isin(d_list)]
# Out:
#   Employee Department  Salary  rank
# 4      Eve    Finance   90000   1.0
# 1      Bob         IT   85000   1.0
# 6    Grace    Finance   82000   2.0
# 5    Frank         IT   75000   2.0
# 2  Charlie         IT   72000   3.0

# %%
df_sorted
# Out:
#   Employee Department  Salary  rank
# 4      Eve    Finance   90000   1.0
# 1      Bob         IT   85000   1.0
# 6    Grace    Finance   82000   2.0
# 5    Frank         IT   75000   2.0
# 2  Charlie         IT   72000   3.0
# 7   Hannah         HR   62000   1.0
# 0    Alice         HR   60000   2.0
# 3    David         HR   58000   3.0

# %%
dep_total_sal = df_sorted.groupby('Department')['Salary'].transform('sum')

# %%
dep_total_sal
# Out:
# 4    172000
# 1    232000
# 6    172000
# 5    232000
# 2    232000
# 7    180000
# 0    180000
# 3    180000
# Name: Salary, dtype: int64

# %%
data = {
    'Employee': ['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Hannah'],
    'Department': ['HR', 'IT', 'IT', 'HR', 'Finance', 'IT', 'Finance', 'HR'],
    'Salary': [60000, np.nan, 72000, np.nan, 90000, 75000, np.nan, 62000]
}

# %%
df = pd.DataFrame(data)

# %%
df.dropna()
# Out:
#   Employee Department   Salary
# 0    Alice         HR  60000.0
# 2  Charlie         IT  72000.0
# 4      Eve    Finance  90000.0
# 5    Frank         IT  75000.0
# 7   Hannah         HR  62000.0

# %%
df['Salary'] = df['Salary'].fillna(df.groupby('Department')['Salary'].transform('mean'))

# %%
df
# Out:
#   Employee Department   Salary
# 0    Alice         HR  60000.0
# 1      Bob         IT  73500.0
# 2  Charlie         IT  72000.0
# 3    David         HR  61000.0
# 4      Eve    Finance  90000.0
# 5    Frank         IT  75000.0
# 6    Grace    Finance  90000.0
# 7   Hannah         HR  62000.0

# %%
# Sample data
customers = {
    'Customer_ID': [1, 2, 3, 4, 5],
    'Name': ['John', 'Jane', 'Bob', 'Alice', 'Mike'],
    'City': ['New York', 'Chicago', 'Boston', 'Chicago', 'Miami']
}

orders = {
    'Order_ID': [101, 102, 103, 104, 105, 106, 107],
    'Customer_ID': [1, 2, 1, 3, 2, 4, 1],
    'Amount': [200, 150, 300, 250, 180, 500, 220]
}

df_customers = pd.DataFrame(customers)
df_orders = pd.DataFrame(orders)

# %%
merged = pd.merge(df_customers,df_orders,on='Customer_ID')

# %%
merged
# Out:
#    Customer_ID   Name      City  Order_ID  Amount
# 0            1   John  New York       101     200
# 1            1   John  New York       103     300
# 2            1   John  New York       107     220
# 3            2   Jane   Chicago       102     150
# 4            2   Jane   Chicago       105     180
# 5            3    Bob    Boston       104     250
# 6            4  Alice   Chicago       106     500

# %%
customer_totals = merged.groupby(['Customer_ID','Name','City'])['Amount'].agg(['sum','count']).reset_index()

# %%
customer_totals
# Out:
#    Customer_ID   Name      City  sum  count
# 0            1   John  New York  720      3
# 1            2   Jane   Chicago  330      2
# 2            3    Bob    Boston  250      1
# 3            4  Alice   Chicago  500      1

# %%
customer_totals.columns = ['Customer_ID', 'Name', 'City', 'Total_Spent', 'Order_Count']

# %%
customer_totals
# Out:
#    Customer_ID   Name      City  Total_Spent  Order_Count
# 0            1   John  New York          720            3
# 1            2   Jane   Chicago          330            2
# 2            3    Bob    Boston          250            1
# 3            4  Alice   Chicago          500            1

# %%
print(customer_totals.sort_values('Total_Spent', ascending=False))
# Out:
#    Customer_ID   Name      City  Total_Spent  Order_Count
# 0            1   John  New York          720            3
# 3            4  Alice   Chicago          500            1
# 1            2   Jane   Chicago          330            2
# 2            3    Bob    Boston          250            1

# %%
# Sample DataFrame
df = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})

# %%
# More complex row function
def row_operation(row):
    return row['A'] * row['B'] + row['C']

df['Custom_Calc'] = df.apply(row_operation, axis=1)
print("\nCustom calculation on each row:")
print(df)
# Out:
# Custom calculation on each row:
#    A   B    C  Custom_Calc
# 0  1  10  100          110
# 1  2  20  200          240
# 2  3  30  300          390
# 3  4  40  400          560
# 4  5  50  500          750

# %%
df['A_times_B'] = df.apply(lambda row: row['A'] * row['B'], axis=1)
print("\nUsing lambda function:")
print(df)
# Out:
# Using lambda function:
#    A   B    C  Custom_Calc  A_times_B
# 0  1  10  100          110         10
# 1  2  20  200          240         40
# 2  3  30  300          390         90
# 3  4  40  400          560        160
# 4  5  50  500          750        250

# %%
def categorize(y):
    if y < 20:
        return "Low"
    elif y < 40:
        return "Medium"
    else:
        return "High"

df['B_Category'] = df['B'].apply(categorize)
print("\nApplying categorical transformation:")
print(df)
# Out:
# Applying categorical transformation:
#    A   B    C  Custom_Calc  A_times_B B_Category
# 0  1  10  100          110         10        Low
# 1  2  20  200          240         40     Medium
# 2  3  30  300          390         90     Medium
# 3  4  40  400          560        160       High
# 4  5  50  500          750        250       High

# %%
X = np.random.rand(100)*10

# %%
Y = 2*X+1+np.random.randn(100)*2

# %%
df = pd.DataFrame(X,Y)

# %%
t = df.reset_index()

# %%
t.columns=['X','Y']

# %%
t
# Out:
#             X         Y
# 0   12.140084  5.428115
# 1   19.905017  9.027806
# 2    0.240147  1.320261
# 3    3.563213  1.016449
# 4   14.069411  6.930479
# ..        ...       ...
# 95  17.811686  7.984178
# 96  15.715550  8.805396
# 97   6.885220  3.381735
# 98   3.755357  1.257866
# 99   1.047081  0.101239
#
# [100 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(t[['X']],t[['Y']],test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
train_error = mean_squared_error(y_train,y_train_pred)
test_error = mean_squared_error(y_test,y_test_pred)

# %%
train_error,test_error
# Out:
# (0.5877697970514808, 0.690633395664653)

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.scatter(X_test, y_test, color='green', label='Testing data')

# %%
import pandas as pd
import regex as re
# import numpy as np
# from openpyxl import load_workbook

def extract_columns_and_values(file_path, target_column_names):
    """
    Extract specific columns and their values from an Excel file where column names 
    can be located anywhere in the sheet.
    
    Parameters:
    file_path (str): Path to the Excel file
    target_column_names (list): List of column names to extract
    
    Returns:
    dict: Dictionary with column names as keys and their values as lists
    """
    # Load the entire Excel file as a DataFrame without headers
    df = pd.read_excel(file_path, header=None)
    
    # Convert to numpy array for easier searching
    data_array = df.values
    
    result = {}
    
    # Initialize with empty lists for each target column
    for col_name in target_column_names:
        result[col_name] = []
    
    # Search for each target column name in the entire sheet
    for col_name in target_column_names:
        # Find all occurrences of the column name in the sheet
        matches = []
        for i in range(data_array.shape[0]):
            for j in range(data_array.shape[1]):
                cell_value = data_array[i, j]
                # Handle NaN values and compare with column name
                print(cell_value)
                if isinstance(cell_value, str) and re.search(col_name,cell_value,re.IGNORECASE):
                    matches.append((i, j))
        
        # For each occurrence of this column name
        for row_idx, col_idx in matches:
            # Extract values below this column name
            values = []
            for r in range(row_idx + 1, data_array.shape[0]):
                cell_value = data_array[r, col_idx]
                # Stop when we hit an empty cell or NaN
                if pd.isna(cell_value) or cell_value == '':
                    break
                values.append(cell_value)
            
            # Add these values to the result
            result[col_name].extend(values)
    
    return result

def main():
    # Example usage
    file_path = r"C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx"
    target_columns = ["Member\sproduct"]  # Replace with your target column names
    print(target_columns)
    
    try:
        extracted_data = extract_columns_and_values(file_path, target_columns)
        print(extracted_data)
        
        # Print the extracted data
        for col_name, values in extracted_data.items():
            print(f"\n{col_name}:")
            for value in values:
                print(f"  - {value}")
        
        # Optionally, save the extracted data to a new Excel file
        output_df = pd.DataFrame(extracted_data)
        output_df.to_excel("extracted_data.xlsx", index=False)
        print("\nExtracted data saved to 'extracted_data.xlsx'")
        
    except Exception as e:
        print(f"An error occurred: {e}")

if __name__ == "__main__":
    main()
# Out:
# ['Member\\sproduct']
# nan
# Project Name: CPR-39014 Metallus, Inc - 212126 - 1/1/25 - New Group Pricing Set Up
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Date of last update:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# Project/Client
# ...

# %%
import regex as re

# %%
text = "hiuhihi #&$() *Member contract code \n fdebdjf"
pattern = "Member\scontract\scode"
re.search(pattern,text,re.IGNORECASE)
# Out:
# <regex.Match object; span=(15, 35), match='Member contract code'>

# %%
import pandas as pd
import argparse
import os
import re
from difflib import get_close_matches

def extract_columns(input_file, output_file=None, columns_to_extract=None):
    """
    Extract specific columns from an Excel file.
    
    Parameters:
        input_file (str): Path to the input Excel file
        output_file (str, optional): Path to save the extracted data
        columns_to_extract (list, optional): List of column names to extract
                                           If None, extracts all mandatory columns
    
    Returns:
        pd.DataFrame: DataFrame containing the extracted columns
    """
    # Default columns to extract (mandatory columns marked with *)
    default_columns = [
        "Member contract code",
        "Source System",
        "Member Product",
        "Coverage",
        "Line of Business",
        "Contracting State",
        "Tiered Product",
        "Reference mixer",
        "Special Handling",
        "Product Name",
        "Network",
        "AltNet",
        "Npar Facility",
        "NPAR Ambulance",
        "NPAR Facility Emergency Room",
        "NPAR Emergency Claim Inst",
        "N/Par Default",
        "Npar Professional",
        "Prof N/Par",
        "Npar RAPS",
        "Npar AERP",
        "Npar Emergency Claims",
        "Npar Assistant Surgeon",
        "Npar Ambulance",
        "Onsite Clinic",
        "Online Providers",
        "Sydney K-Chat",
        "Lark",
        "ASH",
        "Type of mixer work",
        "Special Instructions"
    ]
    
    # Mandatory columns (marked with * in the description)
    mandatory_columns = [
        "Member contract code",
        "Member Product",
        "Reference mixer",
        "Special Handling",
        "Product Name",
        "Network"
    ]
    
    try:
        # Read Excel file
        print(f"Reading Excel file: {input_file}")
        df = pd.read_excel(input_file)
        
        # Clean column names to handle garbage values
        df.columns = [clean_column_name(col) for col in df.columns]
        
        # Match columns with the desired ones, even when they have extra characters
        column_mapping = {}
        for col in df.columns:
            cleaned_col = clean_column_name(col)
            best_match = find_best_match(cleaned_col, default_columns)
            if best_match:
                column_mapping[col] = best_match
                print(f"Matched column '{col}' to '{best_match}'")
        
        # Rename columns in the dataframe
        if column_mapping:
            df = df.rename(columns=column_mapping)
        
        # Determine which columns to extract
        if columns_to_extract is None:
            columns_to_extract = mandatory_columns
        
        # Check for column existence and create a new dataframe with only the desired columns
        columns_found = []
        for col in columns_to_extract:
            if col in df.columns:
                columns_found.append(col)
            else:
                # Try to find a close match for this column
                possible_matches = [c for c in df.columns if col.lower() in c.lower()]
                if possible_matches:
                    best_match = possible_matches[0]
                    columns_found.append(best_match)
                    print(f"Using '{best_match}' for requested column '{col}'")
                else:
                    print(f"Warning: Column '{col}' not found in the Excel file")
        
        if not columns_found:
            print("Error: None of the specified columns were found in the Excel file")
            return None
        
        # Extract only the columns we want
        extracted_df = df[columns_found]
        
        # Save to a new Excel file if output_file is provided
        if output_file:
            directory = os.path.dirname(output_file)
            if directory and not os.path.exists(directory):
                os.makedirs(directory)
            
            extracted_df.to_excel(output_file, index=False)
            print(f"Extracted data saved to: {output_file}")
        
        return extracted_df
    
    except Exception as e:
        print(f"Error processing the Excel file: {str(e)}")
        return None

def clean_column_name(column_name):
    """
    Clean column name by removing garbage values and extra characters.
    
    Parameters:
        column_name (str): Original column name
        
    Returns:
        str: Cleaned column name
    """
    if not isinstance(column_name, str):
        return str(column_name)
    
    # Remove non-alphanumeric characters except spaces and /
    cleaned = re.sub(r'[^\w\s/]', '', column_name)
    
    # Remove extra spaces
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    return cleaned

def find_best_match(column_name, target_columns, threshold=0.6):
    """
    Find the best match for a column name from a list of target columns.
    
    Parameters:
        column_name (str): Column name to match
        target_columns (list): List of target column names
        threshold (float): Minimum similarity score (0-1) to consider a match
        
    Returns:
        str or None: Best matching column name or None if no match found
    """
    # Try exact match first (case insensitive)
    for target in target_columns:
        if column_name.lower() == target.lower():
            return target
    
    # Try contains match
    for target in target_columns:
        if column_name.lower() in target.lower() or target.lower() in column_name.lower():
            # If one is fully contained in the other, it's a good match
            if len(column_name) >= 0.7 * len(target) or len(target) >= 0.7 * len(column_name):
                return target
    
    # Try fuzzy matching
    matches = get_close_matches(column_name.lower(), [t.lower() for t in target_columns], n=1, cutoff=threshold)
    if matches:
        matched_index = [t.lower() for t in target_columns].index(matches[0])
        return target_columns[matched_index]
    
    return None

def main():
    # Set up argument parser
    parser = argparse.ArgumentParser(description='Extract specific columns from an Excel file')
    parser.add_argument('input_file', help='Path to the input Excel file')
    parser.add_argument('-o', '--output_file', help='Path to save the extracted data (optional)')
    parser.add_argument('-c', '--columns', nargs='+', help='List of column names to extract (optional)')
    
    # Parse arguments
    args = parser.parse_args()
    
    # Extract columns
    extract_columns(r"C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx", args.output_file, args.columns)

if __name__ == "__main__":
    main()
# Out:
# Reading Excel file: C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx
# ...
# Error: None of the specified columns were found in the Excel file
# d:\anaconda\envs\llms\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
import pandas as pd
import argparse
import os
import re
from difflib import get_close_matches
import logging

# Set up logging
logging.basicConfig(level=logging.INFO, 
                    format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger('excel_extractor')

def extract_columns(input_file, output_file=None, columns_to_extract=None, verbose=False):
    """
    Extract specific columns from an Excel file.
    
    Parameters:
        input_file (str): Path to the input Excel file
        output_file (str, optional): Path to save the extracted data
        columns_to_extract (list, optional): List of column names to extract
                                           If None, extracts all mandatory columns
        verbose (bool): Enable verbose output for debugging
    
    Returns:
        pd.DataFrame: DataFrame containing the extracted columns
    """
    # Default columns to extract (mandatory columns marked with *)
    default_columns = [
        "Member contract code",
        "Source System",
        "Member Product",
        "Coverage",
        "Line of Business",
        "Contracting State",
        "Tiered Product",
        "Reference mixer",
        "Special Handling",
        "Product Name",
        "Network",
        "AltNet",
        "Npar Facility",
        "NPAR Ambulance",
        "NPAR Facility Emergency Room",
        "NPAR Emergency Claim Inst",
        "N/Par Default",
        "Npar Professional",
        "Prof N/Par",
        "Npar RAPS",
        "Npar AERP",
        "Npar Emergency Claims",
        "Npar Assistant Surgeon",
        "Npar Ambulance",
        "Onsite Clinic",
        "Online Providers",
        "Sydney K-Chat",
        "Lark",
        "ASH",
        "Type of mixer work",
        "Special Instructions"
    ]
    
    # Mandatory columns (marked with * in the description)
    mandatory_columns = [
        "Member contract code",
        "Member Product",
        "Reference mixer",
        "Special Handling",
        "Product Name",
        "Network"
    ]
    
    try:
        logger.info(f"Reading Excel file: {input_file}")
        
        # Try to read the Excel file with verbose debugging
        try:
            # First: Get all sheet names
            xls = pd.ExcelFile(input_file)
            sheet_names = xls.sheet_names
            logger.info(f"Excel file contains these sheets: {sheet_names}")
            
            # Try each sheet to find relevant data
            df = None
            most_matches = 0
            best_sheet = None
            
            for sheet_name in sheet_names:
                logger.info(f"Examining sheet: '{sheet_name}'")
                
                try:
                    # Read the sheet
                    sheet_df = pd.read_excel(input_file, sheet_name=sheet_name)
                    
                    if verbose:
                        logger.info(f"Sheet '{sheet_name}' has {len(sheet_df.columns)} columns and {len(sheet_df)} rows")
                        logger.info(f"Sample columns: {list(sheet_df.columns)[:5]}")
                    
                    # Look for rows with headers - sometimes data starts after a few rows
                    # We'll analyze the first 20 rows to find potential headers
                    for start_row in range(min(20, len(sheet_df))):
                        # Create a new DataFrame starting from this row
                        header_df = sheet_df.iloc[start_row:].copy()
                        
                        # Use this row as the header
                        if len(header_df) > 0:  # Make sure we have data
                            header_row = header_df.iloc[0]
                            
                            # Check if this row contains any column keywords
                            keywords_found = sum(1 for val in header_row if isinstance(val, str) and 
                                               any(keyword.lower() in val.lower() for keyword in 
                                                   ["member", "product", "network", "npar", "mixer"]))
                            
                            if keywords_found >= 3:  # If we found several keywords, use this as header
                                logger.info(f"Found potential header row at index {start_row}")
                                # Set this row as header and skip it in the data
                                header_df.columns = header_df.iloc[0]
                                header_df = header_df.iloc[1:].reset_index(drop=True)
                                
                                # Count potential matches in this configuration
                                potential_matches = 0
                                for col in header_df.columns:
                                    for target in default_columns:
                                        if isinstance(col, str) and (target.lower() in col.lower() or col.lower() in target.lower()):
                                            potential_matches += 1
                                            break
                                
                                if potential_matches > most_matches:
                                    most_matches = potential_matches
                                    best_sheet = sheet_name
                                    df = header_df
                                    logger.info(f"Sheet '{sheet_name}' with header at row {start_row} has {potential_matches} potential column matches")
                    
                    # If we didn't find a good header row, check the original columns
                    if best_sheet is None or best_sheet != sheet_name:
                        potential_matches = 0
                        for col in sheet_df.columns:
                            for target in default_columns:
                                if isinstance(col, str) and (target.lower() in col.lower() or col.lower() in target.lower()):
                                    potential_matches += 1
                                    break
                        
                        if potential_matches > most_matches:
                            most_matches = potential_matches
                            best_sheet = sheet_name
                            df = sheet_df
                            logger.info(f"Sheet '{sheet_name}' with original headers has {potential_matches} potential column matches")
                
                except Exception as e:
                    logger.warning(f"Error processing sheet '{sheet_name}': {str(e)}")
            
            if df is None:
                # If no sheet had obvious matches, use the first sheet
                df = pd.read_excel(input_file, sheet_name=0)
                logger.warning("No obvious matching sheet found. Using the first sheet.")
            else:
                logger.info(f"Selected sheet '{best_sheet}' with {most_matches} potential column matches")
        
        except Exception as sheet_error:
            logger.error(f"Error reading sheets: {str(sheet_error)}")
            # Fallback: try reading without specifying a sheet
            df = pd.read_excel(input_file)
            
        # Debug: show data
        if verbose:
            logger.info("\nFirst 5 rows of data:")
            logger.info(df.head())
            logger.info("\nAll column names found in the file:")
            logger.info(df.columns.tolist())

        # Attempt to handle non-string column names
        df.columns = [str(col) for col in df.columns]
        
        # Clean column names to handle garbage values
        df.columns = [clean_column_name(col) for col in df.columns]
        
        # Check for Excel files with dropdown/choice cells in the header
        # These often contain the format "Column Name - Select..." or similar patterns
        df.columns = [col.split(' - ')[0].split(':')[0].strip() for col in df.columns]
        
        # Match columns with the desired ones, even when they have extra characters
        column_mapping = {}
        for col in df.columns:
            cleaned_col = clean_column_name(col)
            best_match = find_best_match(cleaned_col, default_columns)
            if best_match:
                column_mapping[col] = best_match
                logger.info(f"Matched column '{col}' to '{best_match}'")
        
        # Rename columns in the dataframe
        if column_mapping:
            df = df.rename(columns=column_mapping)
        
        # Determine which columns to extract
        if columns_to_extract is None:
            columns_to_extract = mandatory_columns
        
        # Check for column existence and create a new dataframe with only the desired columns
        columns_found = []
        for col in columns_to_extract:
            if col in df.columns:
                columns_found.append(col)
            else:
                # Try to find a close match for this column
                possible_matches = [c for c in df.columns if col.lower() in c.lower() or c.lower() in col.lower()]
                if possible_matches:
                    best_match = possible_matches[0]
                    columns_found.append(best_match)
                    logger.info(f"Using '{best_match}' for requested column '{col}'")
                else:
                    logger.warning(f"Column '{col}' not found in the Excel file")
        
        if not columns_found:
            logger.error("None of the specified columns were found in the Excel file")
            return None
        
        # Extract only the columns we want
        extracted_df = df[columns_found]
        
        # Save to a new Excel file if output_file is provided
        if output_file:
            directory = os.path.dirname(output_file)
            if directory and not os.path.exists(directory):
                os.makedirs(directory)
            
            extracted_df.to_excel(output_file, index=False)
            logger.info(f"Extracted data saved to: {output_file}")
        
        return extracted_df
    
    except Exception as e:
        logger.error(f"Error processing the Excel file: {str(e)}")
        return None

def clean_column_name(column_name):
    """
    Clean column name by removing garbage values and extra characters.
    
    Parameters:
        column_name (str): Original column name
        
    Returns:
        str: Cleaned column name
    """
    if not isinstance(column_name, str):
        return str(column_name)
    
    # Remove non-alphanumeric characters except spaces and /
    cleaned = re.sub(r'[^\w\s/]', '', column_name)
    
    # Remove extra spaces
    cleaned = re.sub(r'\s+', ' ', cleaned).strip()
    
    return cleaned

def find_best_match(column_name, target_columns, threshold=0.6):
    """
    Find the best match for a column name from a list of target columns.
    
    Parameters:
        column_name (str): Column name to match
        target_columns (list): List of target column names
        threshold (float): Minimum similarity score (0-1) to consider a match
        
    Returns:
        str or None: Best matching column name or None if no match found
    """
    if not column_name or column_name.isspace():
        return None
        
    # Try exact match first (case insensitive)
    for target in target_columns:
        if column_name.lower() == target.lower():
            return target
    
    # Try contains match
    for target in target_columns:
        if column_name.lower() in target.lower() or target.lower() in column_name.lower():
            # If one is fully contained in the other, it's a good match
            if len(column_name) >= 0.7 * len(target) or len(target) >= 0.7 * len(column_name):
                return target
    
    # Try fuzzy matching
    matches = get_close_matches(column_name.lower(), [t.lower() for t in target_columns], n=1, cutoff=threshold)
    if matches:
        matched_index = [t.lower() for t in target_columns].index(matches[0])
        return target_columns[matched_index]
    
    return None

def main():
    # Set up argument parser
    parser = argparse.ArgumentParser(description='Extract specific columns from an Excel file')
    parser.add_argument('input_file', help='Path to the input Excel file')
    parser.add_argument('-o', '--output_file', help='Path to save the extracted data (optional)')
    parser.add_argument('-c', '--columns', nargs='+', help='List of column names to extract (optional)')
    parser.add_argument('-v', '--verbose', action='store_true', help='Enable verbose output for debugging')
    
    # Parse arguments
    args = parser.parse_args()
    
    # Extract columns
    extract_columns(r"C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx", args.output_file, args.columns, args.verbose)

if __name__ == "__main__":
    main()
# Out:
# 2025-05-05 09:44:41,373 - INFO - Reading Excel file: C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx
# 2025-05-05 09:44:41,397 - INFO - Excel file contains these sheets: ['Mixer Form', 'TB Entries', 'NE Additional Questions', 'NY Additional Questions', 'CA Additional Questions', 'Lists']
# 2025-05-05 09:44:41,397 - INFO - Examining sheet: 'Mixer Form'
# d:\anaconda\envs\llms\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# 2025-05-05 09:44:41,978 - INFO - Found potential header row at index 15
# 2025-05-05 09:44:41,978 - INFO - Sheet 'Mixer Form' with header at row 15 has 31 potential column matches
# 2025-05-05 09:44:41,979 - INFO - Found potential header row at index 16
# 2025-05-05 09:44:41,980 - INFO - Found potential header row at index 17
# 2025-05-05 09:44:41,981 - INFO - Examining sheet: 'TB Entries'
# ...

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Lubhawan Parihar\Downloads\CPR-39014 Metallus Inc - 212126 - 010125 - New Group Pricing Set Up Mixer Form.xlsx", sheet_name = 'Mixer Form')
# Out:
# d:\anaconda\envs\llms\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df.head(20)
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                      Project/Client
# 4                                              SSCR #
# 5                       SSCR Sponsor/Initiative Owner
# 6                              Requirements Approvers
# 7                                                 NaN
# 8                                                 NaN
# 9   Test environments: see tab Test Environments f...
# 10                                               IMSI
# 11                                               IMSH
# 12                                               IMSN
# 13                                                NaN
# 14                                                NaN
# 15  Information Required \n(* indicates mandatory ...
# ...

# %%
header_df = None

for start_row in range(min(100, len(df))):
    temp_df = df.iloc[start_row:].copy()
    # print(header_df)

    if len(temp_df)>0:
        header_row = temp_df.iloc[0]

        keywords_found = sum(1 for val in header_row if isinstance(val,str) and any(keyword.lower() in val.lower() for keyword in ["member", "product", "network", "npar", "mixer", "special"]))

        if keywords_found >=4:
            # print(header_row)
            temp_df.columns = temp_df.iloc[0]
            # print(temp_df.columns)
            header_df = temp_df
            header_df = header_df.iloc[1:].reset_index(drop=True)
            break
            # header_df = header_df.iloc[1:].reset_index(drop=True)
            # print(header_df)

# %%
find_case_row = header_df[header_df.columns[0]].str.contains('case', case=False)
find_case_row.dropna(inplace=True)
first_true_idx = find_case_row[find_case_row].index[0]
print(first_true_idx)
# Out:
# 5

# %%
header_df_filtered = header_df.loc[first_true_idx:]

# %%
header_df_filtered
# Out:
# 15 Information Required \n(* indicates mandatory data)  \
# 5                                        Case# 212126
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# ...

# %%
header_df_filtered.reset_index(inplace=True, drop=True)

# %%
mask = header_df_filtered.isna().sum(axis=1)>15
print(mask)

if mask.any():
    first_match_idx = mask[mask].index[0]
    header_df_filtered_new = header_df_filtered.loc[:first_match_idx-1]
else:
    header_df_filtered_new = header_df_filtered.copy()
# Out:
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# dtype: bool

# %%
header_df_filtered_new
# Out:
# 15 Information Required \n(* indicates mandatory data)  \
# 0                                        Case# 212126
# 1                                                 NaN
#
# 15   *Member contract code Source System *Member Product EMO, HMO, PPO,etc.  \
# 0   83SL, 84US, 84UV, 84UX  WPD National                               P1OH
# 1         84V2, 84V6, 84V8  WPD National                               GOHS
#
# 15 Coverage (Scrum Team only supports Medical coverage) Varn   \
# 0                                                 MED    OHA2
# 1                                                 MED    OHA2
#
# 15 Line of Business  \
# 0          National
# 1          National
#
# 15 Contracting State\n (where membership is attached or product is sold)  \
# 0                                                  OH
# 1                                                  OH
#
# 15 Tiered Product  *  \
# 0                 NO
# 1                 NO
#
# ...
